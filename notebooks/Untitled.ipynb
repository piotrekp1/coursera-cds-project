# %%
import pandas as pd 
df = pd.read_hdf('../data/processed/train/aggr_case1.hdf')
df.head()
# Out:
#    shop_id  item_id  item_category_id big_category  month  year  item_cnt_day  \
# 0        2       32                40         Кино      7  2014           1.0
# 1        2       32                40         Кино      8  2015           1.0
# 2        2       32                40         Кино      9  2014           2.0
# 3        2       33                37         Кино      7  2015           1.0
# 4        2       33                37         Кино      9  2014           1.0
#
#    item_cnt_day_sum_1_month  item_cnt_day_std_1_month  item_price_std_1_month  \
# 0                     957.0                  1.294385             2474.960746
# 1                     785.0                  0.353340             1933.133822
# 2                     956.0                  1.057545             2182.333138
# 3                     804.0                  0.562839             2294.877623
# 4                     956.0                  1.057545             2182.333138
#
# ...

# %%
import pandas as pd 
s = pd.Series(['a_b' for _ in range(100)])
s.head()
# Out:
# 0    a_b
# 1    a_b
# 2    a_b
# 3    a_b
# 4    a_b
# dtype: object

# %%
import numpy as np 
np.vstack(s.str.split('_'))[:,0]
# Out:
# array(['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a',
#        'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a',
#        'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a',
#        'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a',
#        'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a',
#        'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a',
#        'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a',
#        'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'], dtype='<U1')

# %%
pd.DataFrame(data=[[2,3], [4,5]]).as_matrix()
# Out:
# array([[2, 3],
#        [4, 5]])
