# %%
import pandas as pd
df_train = pd.read_hdf('../data/processed/train/train_case1.hdf')
df_valid = pd.read_hdf('../data/processed/validation/valid_case1.hdf')
df_train.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  day  \
# 0 2013-01-02               0       59    22154      999.00           1.0    2
# 1 2013-01-03               0       25     2552      899.00           1.0    3
# 2 2013-01-05               0       25     2552      899.00          -1.0    5
# 3 2013-01-06               0       25     2554     1709.05           1.0    6
# 4 2013-01-15               0       25     2555     1099.00           1.0   15
#
#    month  year  weekday     ...      to_new_year_days  is_feb_special_time  \
# 0      1  2013        2     ...                   363                False
# 1      1  2013        3     ...                   362                False
# 2      1  2013        5     ...                   360                False
# 3      1  2013        6     ...                   359                False
# 4      1  2013        1     ...                   350                False
#
#    feb_special_gaussian  from_feb_special_days  to_feb_special_days  \
# 0                   0.0                    314                   51
# 1                   0.0                    315                   50
# 2                   0.0                    317                   48
# 3                   0.0                    318                   47
# 4                   0.0                    327                   38
#
#    is_nov_special_time  nov_special_gaussian  from_nov_special_days  \
# 0                False                   0.0                     88
# 1                False                   0.0                     89
# 2                False                   0.0                     91
# 3                False                   0.0                     92
# 4                False                   0.0                    101
#
#    to_nov_special_days  is_holiday
# 0                  277       False
# 1                  276       False
# 2                  274       False
# 3                  273       False
# 4                  264       False
#
# [5 rows x 24 columns]

# %%
df_items = pd.read_csv('../data/raw/items.csv')
df_categories = pd.read_csv('../data/raw/item_categories.csv')
df_categories['big_category'] = df_categories['item_category_name'].apply(lambda x: x.split()[0])
df_categories.head()
# Out:
#         item_category_name  item_category_id big_category
# 0  PC - Гарнитуры/Наушники                 0           PC
# 1         Аксессуары - PS2                 1   Аксессуары
# 2         Аксессуары - PS3                 2   Аксессуары
# 3         Аксессуары - PS4                 3   Аксессуары
# 4         Аксессуары - PSP                 4   Аксессуары

# %%
item_categories = df_items.set_index('item_id')['item_category_id']
item_big_categories = df_categories.set_index('item_category_id')['big_category']

# %%
df_train = pd.merge(df_train, df_items, on='item_id')
df_train = pd.merge(df_train, df_categories, on='item_category_id')
df_train.columns
# Out:
# Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#        'item_cnt_day', 'day', 'month', 'year', 'weekday', 'days_passed',
#        'is_new_year', 'new_year_gaussian', 'from_new_year_days',
#        'to_new_year_days', 'is_feb_special_time', 'feb_special_gaussian',
#        'from_feb_special_days', 'to_feb_special_days', 'is_nov_special_time',
#        'nov_special_gaussian', 'from_nov_special_days', 'to_nov_special_days',
#        'is_holiday', 'item_name', 'item_category_id', 'item_category_name',
#        'big_category'],
#       dtype='object')

# %%
df_train.columns
# Out:
# Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#        'item_cnt_day', 'day', 'month', 'year', 'weekday', 'days_passed',
#        'is_new_year', 'new_year_gaussian', 'from_new_year_days',
#        'to_new_year_days', 'is_feb_special_time', 'feb_special_gaussian',
#        'from_feb_special_days', 'to_feb_special_days', 'is_nov_special_time',
#        'nov_special_gaussian', 'from_nov_special_days', 'to_nov_special_days',
#        'is_holiday', 'item_name', 'item_category_id', 'item_category_name',
#        'big_category'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (2831747, 28)

# %%
from datetime import date, timedelta
from dateutil.relativedelta import relativedelta
some_time = date(2014,10, 12)
some_time - relativedelta(months=1)
# Out:
# datetime.date(2014, 9, 12)

# %%
timedelta?

# %%
import matplotlib.pyplot as plt
df_train['item_price'].hist()
plt.show()

# %%
df_train['shop_id'].nunique()
# Out:
# 59

# %%
df_train['item_id'].nunique()
# Out:
# 21030

# %%
df_train['month_year'] = df_train['date'].dt.year.astype(str) + '_' + df_train['date'].dt.month.astype(str)
# Out:
# /home/piotrek/.local/lib/python3.5/site-packages/pandas/core/computation/check.py:17: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
shops_granulations = ['shop_id']
items_granulations = ['item_id', 'item_category_id', 'item_big_category']

# %%
df_train.head()
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  day  \
# 0 2013-01-02               0       59    22154       999.0           1.0    2
# 1 2013-01-23               0       24    22154       999.0           1.0   23
# 2 2013-01-20               0       27    22154       999.0           1.0   20
# 3 2013-01-02               0       25    22154       999.0           1.0    2
# 4 2013-01-03               0       25    22154       999.0           1.0    3
#
#    month  year  weekday      ...       to_feb_special_days  \
# 0      1  2013        2      ...                        51
# 1      1  2013        2      ...                        30
# 2      1  2013        6      ...                        33
# 3      1  2013        2      ...                        51
# 4      1  2013        3      ...                        50
#
#    is_nov_special_time  nov_special_gaussian  from_nov_special_days  \
# 0                False                   0.0                     88
# 1                False                   0.0                    109
# 2                False                   0.0                    106
# 3                False                   0.0                     88
# 4                False                   0.0                     89
#
#    to_nov_special_days  is_holiday          item_name  item_category_id  \
# 0                  277       False  ЯВЛЕНИЕ 2012 (BD)                37
# 1                  256       False  ЯВЛЕНИЕ 2012 (BD)                37
# 2                  259       False  ЯВЛЕНИЕ 2012 (BD)                37
# 3                  277       False  ЯВЛЕНИЕ 2012 (BD)                37
# 4                  276       False  ЯВЛЕНИЕ 2012 (BD)                37
#
#    item_category_name  big_category
# 0      Кино - Blu-Ray          Кино
# 1      Кино - Blu-Ray          Кино
# 2      Кино - Blu-Ray          Кино
# 3      Кино - Blu-Ray          Кино
# 4      Кино - Blu-Ray          Кино
#
# [5 rows x 28 columns]

# %%
def tolist(agg): return [agg] if type(agg) == str else list(agg)
def get_aggregates(df, 
                   year, month,
                   from_reldelta, to_reldelta=relativedelta(days=0)
                  ):
    agg_functions = {
        'item_price': ['std'],
        'item_cnt_day': ['sum', 'std']
    }
    agg_objects = list(agg_functions.keys())
    shops_granulation = 'shop_id'
    items_granulations = ['item_id', 'item_category_id', 'big_category']
    
    print(year, month, from_reldelta)
    
    from_time = date(year,month, 1) - from_reldelta
    to_time = date(year, month, 1) - to_reldelta
    
    time_constraints = (df['date'] >= from_time) & (df['date'] < to_time)
    df_time_constrained = df[time_constraints]
    
    object_aggregates = [
        shops_granulation,
        *items_granulations +
        [ (shops_granulation, items_granulation) for items_granulation in items_granulations]
    ]

    aggregates = {
        agg_by: df_time_constrained.groupby(tolist(agg_by), as_index=False)[agg_objects].agg(agg_functions)
        for agg_by in object_aggregates
    }
    return aggregates
get_aggregates(df_train, 2015, 9, relativedelta(months=3))[('shop_id')]
# Out:
# 2015 9 relativedelta(months=+3)
#    shop_id item_cnt_day             item_price
#                     sum       std          std
# 0        2       2531.0  0.464250  1862.469055
# 1        3       1873.0  0.404253  2031.692566
# 2        4       2582.0  0.540442  1649.918470
# 3        5       3239.0  0.425773  1500.612405
# 4        6       4598.0  0.567381  1938.531023
# 5        7       3971.0  0.422306  1876.308067
# 6       10       1332.0  0.660112  1686.256899
# 7       12       4855.0  2.558523  2279.098333
# 8       14       3034.0  1.145021  1832.275855
# 9       15       4008.0  1.642012  1990.558205
# 10      16       3383.0  0.502042  1692.695926
# 11      18       3383.0  0.716036  1995.136422
# 12      19       4273.0  0.463204  1827.193420
# 13      21       5207.0  1.519475  1863.229802
# 14      22       3139.0  0.747962  1836.402613
# 15      24       3082.0  0.503640  1637.395999
# 16      25      14444.0  1.274898  1668.754743
# 17      26       3149.0  0.722496  1610.991627
# 18      27       5835.0  0.898423  2004.817165
# 19      28      11282.0  1.088927  1571.276971
# 20      31      17861.0  1.337851  1435.857830
# 21      34       1329.0  0.875897  2207.683918
# 22      35       4179.0  0.629217  1963.739234
# 23      37       3093.0  0.632896  1781.456182
# 24      38       4276.0  2.497185  2297.361310
# 25      39       2190.0  0.915505  1937.856270
# 26      41       2309.0  0.695810  1988.294369
# 27      42      11028.0  1.522314  1786.933927
# 28      44       2066.0  0.402747  1656.554158
# 29      45       2007.0  0.511591  1783.359437
# 30      46       4849.0  1.097496  1737.879884
# 31      47       5443.0  1.235930  1723.535876
# 32      48       3400.0  0.335777  1930.297939
# 33      49       2611.0  0.452705  1762.810317
# 34      50       3107.0  0.438843  2148.034378
# 35      51       2323.0  0.248219  1360.454973
# 36      52       2580.0  0.429695  1769.331419
# 37      53       3653.0  0.508103  1552.558941
# 38      55       5543.0  1.752723  1065.181886
# 39      56       4661.0  0.975787  1589.462717
# 40      57       7572.0  0.484835  1616.262348
# 41      58       4981.0  0.362140  1848.638955
# 42      59       3119.0  1.615253  1658.858986

# %%
cur_date = date(2015, 9, 1)

# %%
df_train.columns
# Out:
# Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#        'item_cnt_day', 'day', 'month', 'year', 'weekday', 'days_passed',
#        'is_new_year', 'new_year_gaussian', 'from_new_year_days',
#        'to_new_year_days', 'is_feb_special_time', 'feb_special_gaussian',
#        'from_feb_special_days', 'to_feb_special_days', 'is_nov_special_time',
#        'nov_special_gaussian', 'from_nov_special_days', 'to_nov_special_days',
#        'is_holiday', 'item_name', 'item_category_id', 'item_category_name',
#        'big_category', 'month_year'],
#       dtype='object')

# %%
now = relativedelta(days=0)
dates = {
    '1_month': (relativedelta(months=1), now),
    '3_months': (relativedelta(months=3), now),
    '6_months': (relativedelta(months=6), now),
#    'year': (relativedelta(months=12), now),
    '1_month_ago': (relativedelta(months=2), relativedelta(months=1))
#    '2_quartals_ago': (relativedelta(months=9), relativedelta(months=6)),
}

# %%
date_aggregates
# Out:
# {'1_month': {('shop_id',
#    'big_category'):                      item_price                            item_cnt_day  \
#                             count          mean          std        count
#   shop_id big_category
#   2       Аксессуары           24   2454.125000  1791.908196           24
#           Игровые               1  25392.000000          NaN            1
#           Игры                514   1155.323040   956.365731          514
#           Карты                16   1333.375000   656.688346           16
#           Кино                137    304.970803   245.216859          137
#           Книги                12    733.416667   453.971256           12
#           Музыка                7    534.714286   383.747189            7
#           Подарки             123    935.829268   797.313848          123
#           Программы             6   1538.000000   891.573665            6
#           Служебные             2    916.666667   589.255651            2
#           Элементы              3    159.000000    34.641016            3
#   3       Аксессуары           26   1966.807692  1609.383386           26
#           Игровые               4  27990.000000  2828.427125            4
#           Игры                282   1239.584905   870.819485          282
#           Карты                17   1504.852941   742.243974           17
#           Кино                 96    321.385417   191.627235           96
#           Книги                 5    309.200000    55.183331            5
#           Музыка               64    329.625000   146.589536           64
#           Подарки              96    699.916875   697.620502           96
#           Программы             4   1595.000000  1258.054053            4
#           Служебные            10    994.900000   240.887456           10
#           Элементы              3    139.000000    34.641016            3
#   4       Аксессуары           25   2456.840000  1604.801927           25
#           Игровые               4  22541.875000  8005.410508            4
#           Игры                382    983.745271   800.392527          382
#           Карты                 8   2211.500000   931.109170            8
#           Кино                141    372.326241   531.466173          141
#           Книги                 7    594.857143   369.432190            7
#           Музыка              123    299.967480   168.376673          123
#           Подарки             124    594.911290   663.439278          124
#   ...                         ...           ...          ...          ...
#   57      Карты                23   1453.304348   777.240877           23
#           Кино                950    300.265439   234.918160          950
#           Книги                18    912.666667   386.511091           18
#           Музыка              467    339.261242   321.045289          467
#           Подарки             305    829.149197   770.863039          305
#           Программы            74   2151.148649  1816.558945           74
#           Служебные             7    613.857143   388.151787            7
#           Элементы              8    141.500000    31.052950            8
#   58      Аксессуары           43   2104.895349  1581.587545           43
#           Игровые              11  20126.325758  7239.130253           11
#           Игры                552   1252.265399   876.455881          552
#           Карты                14   1648.964286   893.069479           14
#           Кино                482    266.609959   172.318775          482
#           Книги                19    846.684211   370.030337           19
#           Музыка              147    311.238095   144.496876          147
#           Подарки             311    942.199357   834.487650          311
#           Программы            25   1899.560000  1443.968723           25
#           Служебные             4   1724.000000   846.069343            4
#           Элементы              4    119.000000     0.000000            4
#   59      Аксессуары           24   2104.791667  1675.143991           24
#           Игровые               2  24695.000000   985.706853            2
#           Игры                460    905.317543   766.216204          460
#           Карты                11   1621.727273   935.244256           11
#           Кино                160    341.737500   243.598713          160
#           Книги                14    697.142857   412.213137           14
#           Музыка               86    386.534884   454.229009           86
#           Подарки             183    820.797814   778.196370          183
#           Программы            12   2182.416667  1566.605796           12
#           Служебные            14   1031.261905   773.872902           14
#           Элементы              7    127.571429    22.677868            7
#
#
#                             mean       std
#   shop_id big_category
#   2       Аксессуары    1.083333  0.282330
#           Игровые       1.000000       NaN
#           Игры          1.161479  0.547184
#           Карты         1.062500  0.250000
#           Кино          1.000000  0.000000
#           Книги         1.083333  0.288675
#           Музыка        1.142857  0.377964
#           Подарки       1.048780  0.251346
#           Программы     1.000000  0.000000
#           Служебные     2.000000  1.414214
#           Элементы      1.333333  0.577350
#   3       Аксессуары    1.115385  0.431455
#           Игровые       1.250000  0.500000
#           Игры          1.060284  0.413195
#           Карты         1.352941  0.606339
#           Кино          1.000000  0.000000
#           Книги         1.000000  0.000000
#           Музыка        1.015625  0.125000
#           Подарки       1.250000  0.664910
#           Программы     1.000000  0.000000
#           Служебные     1.500000  0.527046
#           Элементы      1.666667  0.577350
#   4       Аксессуары    1.040000  0.200000
#           Игровые       0.500000  1.000000
#           Игры          1.065445  0.321430
#           Карты         1.000000  0.000000
#           Кино          1.014184  0.118672
#           Книги         1.000000  0.000000
#           Музыка        1.000000  0.000000
#           Подарки       1.596774  1.681653
#   ...                        ...       ...
#   57      Карты         1.086957  0.288104
#           Кино          1.053684  0.315163
#           Книги         1.000000  0.000000
#           Музыка        1.025696  0.183502
#           Подарки       1.340984  1.045884
#           Программы     1.135135  0.344201
#           Служебные     1.142857  0.377964
#           Элементы      1.625000  0.517549
#   58      Аксессуары    1.116279  0.543766
#           Игровые       1.272727  0.646670
#           Игры          1.115942  0.456014
#           Карты         1.142857  0.534522
#           Кино          1.014523  0.119757
#           Книги         1.000000  0.000000
#           Музыка        0.993197  0.184932
#           Подарки       1.128617  0.529319
#           Программы     1.120000  0.331662
#           Служебные     1.000000  0.000000
#           Элементы      1.750000  0.500000
#   59      Аксессуары    1.041667  0.204124
#           Игровые       1.000000  0.000000
#           Игры          1.463043  3.808708
#           Карты         1.090909  0.301511
#           Кино          1.006250  0.079057
#           Книги         1.000000  0.000000
#           Музыка        1.011628  0.107833
#           Подарки       1.092896  0.428521
#           Программы     1.000000  0.000000
#           Служебные     1.285714  0.611250
#           Элементы      1.428571  0.534522
#
#   [453 rows x 6 columns],
#   ('shop_id',
#    'item_category_id'):                          item_price                            item_cnt_day  \
#                                 count          mean          std        count
#   shop_id item_category_id
#   2       3                        11   2298.636364  2068.274270           11
#           5                         2    699.000000     0.000000            2
#           6                         7   2763.857143  1840.496349            7
#           7                         4   3217.250000   663.704440            4
#           12                        1  25392.000000          NaN            1
#           19                       95    993.511509   606.476930           95
#           20                       79   2174.157776  1285.383777           79
#           21                        4    549.000000   313.581462            4
#           22                        9   1254.444444   255.424701            9
#           23                      108   1055.314676   580.660407          108
#           24                       31   1863.500000  1036.230179           31
#           25                        6   2165.666667  1727.039857            6
#           28                       38    890.788947   475.019780           38
#           29                        1   5198.000000          NaN            1
#           30                      143    632.332308   572.085599          143
#           33                        8   1074.000000    70.710678            8
#           35                        8   1592.750000   874.821410            8
#           37                       38    465.578947   325.794466           38
#           38                       16    367.750000   276.812211           16
#           40                       83    219.337349   132.945641           83
#           42                        7   1043.714286   327.721281            7
#           49                        5    299.000000    35.355339            5
#           55                        6    390.666667    49.159604            6
#           58                        1   1399.000000          NaN            1
#           61                       13   1545.153846   985.406333           13
#           63                       27    910.111111   448.118574           27
#           64                       14   1313.285714   687.925692           14
#           65                       13    369.000000   100.995049           13
#   [1754 rows x 6 columns],
#   ('shop_id',
#    'item_id'):                 item_price                         item_cnt_day            \
#                        count        mean         std        count      mean
#   shop_id item_id
#   2       32               1   149.00000         NaN            1  1.000000
#           70               1   349.00000         NaN            1  1.000000
#           482              1  3300.00000         NaN            1  1.000000
#           792              2   979.00000    0.000000            2  1.000000
#           806              1   249.00000         NaN            1  1.000000
#           832              1   299.00000         NaN            1  1.000000
#           948              2   649.00000  494.974747            2  4.500000
#           949              1   299.00000         NaN            1  1.000000
#           951              1   899.00000         NaN            1  1.000000
#           1384             1   198.00000         NaN            1  1.000000
#           1389             2  1498.00000  141.421356            2  1.000000
#           1391             1   998.00000         NaN            1  1.000000
#           1413             1   999.00000         NaN            1  1.000000
#           1464             1   499.50000         NaN            1  2.000000
#           1465             2   439.49000   56.554400            2  1.500000
#           1466             1   499.50000         NaN            1  2.000000
#           1469             3   839.34000  317.202911            3  1.000000
#           1483             2   522.22500   32.138003            2  1.500000
#           1484             4   655.36250   64.859051            4  1.000000
#           1486             4   934.70375  305.475131            4  1.250000
#           1495             1   499.00000         NaN            1  2.000000
#           1515             1   899.50000         NaN            1  1.000000
#           1523             2   799.00000    0.000000            2  1.000000
#           1535             2  1499.25000  706.753228            2  1.500000
#           1537             2   499.50000    0.000000            2  1.500000
#           1538             3   399.50000    0.000000            3  1.333333
#           1539             1  1199.00000         NaN            1  1.000000
#           1540             5  1032.24600   49.375157            5  1.000000
#           1547             1  5599.00000         NaN            1  1.000000
#           1555             2   899.25000  423.910515            2  1.000000
#   ...                    ...         ...         ...          ...       ...
#   59      20624            1   649.00000         NaN            1  1.000000
#           20627            1   649.00000         NaN            1  1.000000
#           20629            2  2399.00000    0.000000            2  1.000000
#           20630            2  2279.00000  169.705627            2  1.000000
#           20732            1   399.00000         NaN            1  1.000000
#           20866            2   629.00000   98.994949            2  1.000000
#           20949           18     5.00000    0.000000           18  1.833333
#           20951            1   999.00000         NaN            1  1.000000
#           21366            1  1599.00000         NaN            1  1.000000
#           21377            1   169.00000         NaN            1  1.000000
#           21386            1   169.00000         NaN            1  1.000000
#           21394            1   349.00000         NaN            1  1.000000
#           21440            1   149.00000         NaN            1  1.000000
#           21443            1   149.00000         NaN            1  1.000000
#           21536            1   229.00000         NaN            1  1.000000
#           21562            2   229.00000    0.000000            2  1.000000
#           21575            1   299.00000         NaN            1  1.000000
#           21597            1   229.00000         NaN            1  1.000000
#           21624            1   299.00000         NaN            1  1.000000
#           21669            2   149.00000    0.000000            2  1.000000
#           21673            1   299.00000         NaN            1  1.000000
#           21961            1   579.00000         NaN            1  1.000000
#           21967            1   579.00000         NaN            1  1.000000
#           21968            2   949.00000    0.000000            2  0.000000
#           22087            1   119.00000         NaN            1  2.000000
#           22088            5   119.00000    0.000000            5  1.400000
#           22092            1   179.00000         NaN            1  1.000000
#           22102            2  1250.00000    0.000000            2  1.000000
#           22105            1   199.00000         NaN            1  1.000000
#           22162            1   349.00000         NaN            1  1.000000
#
#
#                         std
#   shop_id item_id
#   2       32            NaN
#           70            NaN
#           482           NaN
#           792      0.000000
#           806           NaN
#           832           NaN
#           948      4.949747
#           949           NaN
#           951           NaN
#           1384          NaN
#           1389     0.000000
#           1391          NaN
#           1413          NaN
#           1464          NaN
#           1465     0.707107
#           1466          NaN
#           1469     0.000000
#           1483     0.707107
#           1484     0.000000
#           1486     0.500000
#           1495          NaN
#           1515          NaN
#           1523     0.000000
#           1535     0.707107
#           1537     0.707107
#           1538     0.577350
#           1539          NaN
#           1540     0.000000
#           1547          NaN
#           1555     0.000000
#   ...                   ...
#   59      20624         NaN
#           20627         NaN
#           20629    0.000000
#           20630    0.000000
#           20732         NaN
#           20866    0.000000
#           20949    0.923548
#           20951         NaN
#           21366         NaN
#           21377         NaN
#           21386         NaN
#           21394         NaN
#           21440         NaN
#           21443         NaN
#           21536         NaN
#           21562    0.000000
#           21575         NaN
#           21597         NaN
#           21624         NaN
#           21669    0.000000
#           21673         NaN
#           21961         NaN
#           21967         NaN
#           21968    1.414214
#           22087         NaN
#           22088    0.547723
#           22092         NaN
#           22102    0.000000
#           22105         NaN
#           22162         NaN
#
#   [33486 rows x 6 columns],
#   'big_category':              item_price                            item_cnt_day            \
#                     count          mean          std        count      mean
#   big_category
#   Аксессуары         1575   2222.625780  1759.930958         1575  1.102857
#   Билеты              122   1127.868852   191.238804          122  3.959016
#   Доставка             94    702.543566   632.857850           94  2.936170
#   Игровые             235  21900.287887  8695.278139          235  1.093617
#   Игры              20490   1171.108722   960.772675        20490  1.152562
#   Карты               847   1631.726509   867.001334          847  1.374262
#   Кино              12551    364.863942   385.605420        12551  1.043503
#   Книги              2540    546.452909   374.196007         2540  1.075591
#   Музыка             6905    412.111751   499.811585         6905  1.007965
#   Подарки            9946    876.113636   804.828862         9946  1.351599
#   Программы           937   1899.804525  1994.342928          937  1.122732
#   Служебные           591   1174.582105   780.015814          591  1.639594
#   Элементы            196    131.800357    27.179252          196  1.494898
#
#
#                      std
#   big_category
#   Аксессуары    0.471107
#   Билеты        3.276255
#   Доставка      2.289802
#   Игровые       0.443088
#   Игры          0.983466
#   Карты         0.810947
#   Кино          0.302479
#   Книги         0.341144
#   Музыка        0.136460
#   Подарки       2.162653
#   Программы     0.505193
#   Служебные     0.986548
#   Элементы      0.885770  ,
#   'item_category_id':                  item_price                             item_cnt_day  \
#                         count          mean           std        count
#   item_category_id
#   2                       129   2493.208992    721.839908          129
#   3                       860   2147.496911   1837.169807          860
#   4                         1     58.000000           NaN            1
#   5                        45    575.638667    178.875139           45
#   6                       260   2477.351923   1509.725239          260
#   7                       280   2364.610929   2033.721641          280
#   8                       122   1127.868852    191.238804          122
#   9                        94    702.543566    632.857850           94
#   11                       11  14990.000000      0.000000           11
#   12                      107  24402.214953  10675.633349          107
#   14                        2   6494.000000   3529.877052            2
#   15                       47  14313.504752   2627.321763           47
#   16                       68  24778.204853   2263.496756           68
#   19                     4144   1140.894671    653.849531         4144
#   20                     3532   2201.251579   1285.557240         3532
#   21                      204    636.008775    268.506401          204
#   22                      404   1175.452475    372.321172          404
#   57           35164   936.801179  1979.533793        35164  1.179303   1.001414
#   58           23402   971.173634  1990.794982        23402  1.152252   0.868533
#   59           12197  1085.455794  2171.199260        12197  1.205870   1.371178}}

# %%
def date_condition(year, month): return ((month == 9) & (year == 2014)) | (month.isin([6,7,8]) & (year == 2015))

# %%
df_agg_train = df_train[['shop_id', 'item_id', 'item_category_id', 'big_category', 'month', 'year', 'date', 'item_cnt_day']]
x_cols = ['shop_id', 'item_id', 'item_category_id', 'big_category', 'month', 'year']
df_agg_train = df_agg_train.groupby(x_cols, as_index=False)['item_cnt_day'].sum()
df_agg_train = df_agg_train[date_condition(df_agg_train['year'], df_agg_train['month'])]
print(df_agg_train.shape)

counter = 0 
for _, el in df_agg_train[['year', 'month']].drop_duplicates().iterrows():
    counter += 1
    print(counter)
    aggs = dict()
    for date_name, curdate in dates.items():
        print(date)
        for agg_keys, agg_df in get_aggregates(df_train, el['year'], el['month'], *curdate).items():
            agg_keys = agg_keys
            print(agg_df.columns)
            agg_df.columns = [ '_'.join(list(col) + [date_name]).rstrip('_') if col[1] != '' else col[0] for col in agg_df.columns ]
            agg_df['year'] = el['year']
            agg_df['month'] = el['month']
            
            print(df_agg_train.columns)
            print(agg_df.columns)
            print('s')
            aggs[agg_keys] = pd.concat([aggs.get(agg_keys, pd.DataFrame()), agg_df])

for agg_keys, agg_df in aggs.items():
    print(agg_df.columns)
    print(df_agg_train.columns)
    df_agg_train = pd.merge(df_agg_train,
                            agg_df, 
                            on=tolist(agg_keys) + ['year', 'month'], 
                            how='left', 
                            suffixes=('','_'.join(tolist(agg_keys)))
                           )
print(df_agg_train.shape)
# Out:
# (139345, 7)
# 1
# <class 'datetime.date'>
# 2015 8 relativedelta(months=+3)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_3_months', 'item_cnt_day_std_3_months',
#        'item_price_std_3_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_3_months', 'item_cnt_day_std_3_months',
#        'item_price_std_3_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# <class 'datetime.date'>
# 2015 8 relativedelta(months=+1)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_1_month', 'item_cnt_day_std_1_month',
#        'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_1_month', 'item_cnt_day_std_1_month',
#        'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_1_month', 'item_cnt_day_std_1_month',
#        'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# <class 'datetime.date'>
# 2015 8 relativedelta(months=+6)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_6_months', 'item_cnt_day_std_6_months',
#        'item_price_std_6_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_6_months', 'item_cnt_day_std_6_months',
#        'item_price_std_6_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# <class 'datetime.date'>
# 2015 8 relativedelta(months=+2)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# 2
# <class 'datetime.date'>
# 2014 9 relativedelta(months=+3)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_3_months', 'item_cnt_day_std_3_months',
#        'item_price_std_3_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_3_months', 'item_cnt_day_std_3_months',
#        'item_price_std_3_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# <class 'datetime.date'>
# 2014 9 relativedelta(months=+1)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_1_month', 'item_cnt_day_std_1_month',
#        'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_1_month', 'item_cnt_day_std_1_month',
#        'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_1_month', 'item_cnt_day_std_1_month',
#        'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# <class 'datetime.date'>
# 2014 9 relativedelta(months=+6)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_6_months', 'item_cnt_day_std_6_months',
#        'item_price_std_6_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_6_months', 'item_cnt_day_std_6_months',
#        'item_price_std_6_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# <class 'datetime.date'>
# 2014 9 relativedelta(months=+2)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# 3
# <class 'datetime.date'>
# 2015 7 relativedelta(months=+3)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_3_months', 'item_cnt_day_std_3_months',
#        'item_price_std_3_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_3_months', 'item_cnt_day_std_3_months',
#        'item_price_std_3_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# <class 'datetime.date'>
# 2015 7 relativedelta(months=+1)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_1_month', 'item_cnt_day_std_1_month',
#        'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_1_month', 'item_cnt_day_std_1_month',
#        'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_1_month', 'item_cnt_day_std_1_month',
#        'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# <class 'datetime.date'>
# 2015 7 relativedelta(months=+6)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_6_months', 'item_cnt_day_std_6_months',
#        'item_price_std_6_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_6_months', 'item_cnt_day_std_6_months',
#        'item_price_std_6_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# <class 'datetime.date'>
# 2015 7 relativedelta(months=+2)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# 4
# <class 'datetime.date'>
# 2015 6 relativedelta(months=+3)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_3_months', 'item_cnt_day_std_3_months',
#        'item_price_std_3_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_3_months', 'item_cnt_day_std_3_months',
#        'item_price_std_3_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_std_3_months', 'item_price_std_3_months', 'year',
#        'month'],
#       dtype='object')
# s
# <class 'datetime.date'>
# 2015 6 relativedelta(months=+1)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_1_month', 'item_cnt_day_std_1_month',
#        'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_1_month', 'item_cnt_day_std_1_month',
#        'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_std_1_month', 'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_1_month', 'item_cnt_day_std_1_month',
#        'item_price_std_1_month', 'year', 'month'],
#       dtype='object')
# s
# <class 'datetime.date'>
# 2015 6 relativedelta(months=+6)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_6_months', 'item_cnt_day_std_6_months',
#        'item_price_std_6_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_6_months', 'item_cnt_day_std_6_months',
#        'item_price_std_6_months', 'year', 'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_6_months',
#        'item_cnt_day_std_6_months', 'item_price_std_6_months', 'year',
#        'month'],
#       dtype='object')
# s
# <class 'datetime.date'>
# 2015 6 relativedelta(months=+2)
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'shop_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_category_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category', 'shop_id'], ['std', 'sum', '']],
#            labels=[[3, 2, 0, 0, 1], [2, 2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['shop_id', 'big_category', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'item_category_id'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# MultiIndex(levels=[['item_cnt_day', 'item_price', 'big_category'], ['std', 'sum', '']],
#            labels=[[2, 0, 0, 1], [2, 1, 0, 0]])
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_std_1_month_ago', 'item_price_std_1_month_ago', 'year',
#        'month'],
#       dtype='object')
# s
# Index(['item_cnt_day_std_1_month', 'item_cnt_day_std_1_month_ago',
#        'item_cnt_day_std_3_months', 'item_cnt_day_std_6_months',
#        'item_cnt_day_sum_1_month', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_sum_3_months', 'item_cnt_day_sum_6_months',
#        'item_price_std_1_month', 'item_price_std_1_month_ago',
#        'item_price_std_3_months', 'item_price_std_6_months', 'month',
#        'shop_id', 'year'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_std_1_month',
#        'item_cnt_day_std_1_month_ago', 'item_cnt_day_std_3_months',
#        'item_cnt_day_std_6_months', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_sum_1_month_ago', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_sum_6_months', 'item_price_std_1_month',
#        'item_price_std_1_month_ago', 'item_price_std_3_months',
#        'item_price_std_6_months', 'month', 'year'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day', 'item_cnt_day_std_1_month',
#        'item_cnt_day_std_1_month_ago', 'item_cnt_day_std_3_months',
#        'item_cnt_day_std_6_months', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_sum_1_month_ago', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_sum_6_months', 'item_price_std_1_month',
#        'item_price_std_1_month_ago', 'item_price_std_3_months',
#        'item_price_std_6_months'],
#       dtype='object')
# Index(['item_category_id', 'item_cnt_day_std_1_month',
#        'item_cnt_day_std_1_month_ago', 'item_cnt_day_std_3_months',
#        'item_cnt_day_std_6_months', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_sum_1_month_ago', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_sum_6_months', 'item_price_std_1_month',
#        'item_price_std_1_month_ago', 'item_price_std_3_months',
#        'item_price_std_6_months', 'month', 'shop_id', 'year'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day', 'item_cnt_day_std_1_month',
#        'item_cnt_day_std_1_month_ago', 'item_cnt_day_std_3_months',
#        'item_cnt_day_std_6_months', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_sum_1_month_ago', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_sum_6_months', 'item_price_std_1_month',
#        'item_price_std_1_month_ago', 'item_price_std_3_months',
#        'item_price_std_6_months', 'item_cnt_day_std_1_monthbig_category',
#        'item_cnt_day_std_1_month_agobig_category',
#        'item_cnt_day_std_3_monthsbig_category',
#        'item_cnt_day_std_6_monthsbig_category',
#        'item_cnt_day_sum_1_monthbig_category',
#        'item_cnt_day_sum_1_month_agobig_category',
#        'item_cnt_day_sum_3_monthsbig_category',
#        'item_cnt_day_sum_6_monthsbig_category',
#        'item_price_std_1_monthbig_category',
#        'item_price_std_1_month_agobig_category',
#        'item_price_std_3_monthsbig_category',
#        'item_price_std_6_monthsbig_category'],
#       dtype='object')
# Index(['item_cnt_day_std_1_month', 'item_cnt_day_std_1_month_ago',
#        'item_cnt_day_std_3_months', 'item_cnt_day_std_6_months',
#        'item_cnt_day_sum_1_month', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_sum_3_months', 'item_cnt_day_sum_6_months', 'item_id',
#        'item_price_std_1_month', 'item_price_std_1_month_ago',
#        'item_price_std_3_months', 'item_price_std_6_months', 'month', 'year'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day', 'item_cnt_day_std_1_month',
#        'item_cnt_day_std_1_month_ago', 'item_cnt_day_std_3_months',
#        'item_cnt_day_std_6_months', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_sum_1_month_ago', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_sum_6_months', 'item_price_std_1_month',
#        'item_price_std_1_month_ago', 'item_price_std_3_months',
#        'item_price_std_6_months', 'item_cnt_day_std_1_monthbig_category',
#        'item_cnt_day_std_1_month_agobig_category',
#        'item_cnt_day_std_3_monthsbig_category',
#        'item_cnt_day_std_6_monthsbig_category',
#        'item_cnt_day_sum_1_monthbig_category',
#        'item_cnt_day_sum_1_month_agobig_category',
#        'item_cnt_day_sum_3_monthsbig_category',
#        'item_cnt_day_sum_6_monthsbig_category',
#        'item_price_std_1_monthbig_category',
#        'item_price_std_1_month_agobig_category',
#        'item_price_std_3_monthsbig_category',
#        'item_price_std_6_monthsbig_category',
#        'item_cnt_day_std_1_monthshop_id_item_category_id',
#        'item_cnt_day_std_1_month_agoshop_id_item_category_id',
#        'item_cnt_day_std_3_monthsshop_id_item_category_id',
#        'item_cnt_day_std_6_monthsshop_id_item_category_id',
#        'item_cnt_day_sum_1_monthshop_id_item_category_id',
#        'item_cnt_day_sum_1_month_agoshop_id_item_category_id',
#        'item_cnt_day_sum_3_monthsshop_id_item_category_id',
#        'item_cnt_day_sum_6_monthsshop_id_item_category_id',
#        'item_price_std_1_monthshop_id_item_category_id',
#        'item_price_std_1_month_agoshop_id_item_category_id',
#        'item_price_std_3_monthsshop_id_item_category_id',
#        'item_price_std_6_monthsshop_id_item_category_id'],
#       dtype='object')
# Index(['big_category', 'item_cnt_day_std_1_month',
#        'item_cnt_day_std_1_month_ago', 'item_cnt_day_std_3_months',
#        'item_cnt_day_std_6_months', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_sum_1_month_ago', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_sum_6_months', 'item_price_std_1_month',
#        'item_price_std_1_month_ago', 'item_price_std_3_months',
#        'item_price_std_6_months', 'month', 'shop_id', 'year'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day', 'item_cnt_day_std_1_month',
#        'item_cnt_day_std_1_month_ago', 'item_cnt_day_std_3_months',
#        'item_cnt_day_std_6_months', 'item_cnt_day_sum_1_month',
#        'item_cnt_day_sum_1_month_ago', 'item_cnt_day_sum_3_months',
#        'item_cnt_day_sum_6_months', 'item_price_std_1_month',
#        'item_price_std_1_month_ago', 'item_price_std_3_months',
#        'item_price_std_6_months', 'item_cnt_day_std_1_monthbig_category',
#        'item_cnt_day_std_1_month_agobig_category',
#        'item_cnt_day_std_3_monthsbig_category',
#        'item_cnt_day_std_6_monthsbig_category',
#        'item_cnt_day_sum_1_monthbig_category',
#        'item_cnt_day_sum_1_month_agobig_category',
#        'item_cnt_day_sum_3_monthsbig_category',
#        'item_cnt_day_sum_6_monthsbig_category',
#        'item_price_std_1_monthbig_category',
#        'item_price_std_1_month_agobig_category',
#        'item_price_std_3_monthsbig_category',
#        'item_price_std_6_monthsbig_category',
#        'item_cnt_day_std_1_monthshop_id_item_category_id',
#        'item_cnt_day_std_1_month_agoshop_id_item_category_id',
#        'item_cnt_day_std_3_monthsshop_id_item_category_id',
#        'item_cnt_day_std_6_monthsshop_id_item_category_id',
#        'item_cnt_day_sum_1_monthshop_id_item_category_id',
#        'item_cnt_day_sum_1_month_agoshop_id_item_category_id',
#        'item_cnt_day_sum_3_monthsshop_id_item_category_id',
#        'item_cnt_day_sum_6_monthsshop_id_item_category_id',
#        'item_price_std_1_monthshop_id_item_category_id',
#        'item_price_std_1_month_agoshop_id_item_category_id',
#        'item_price_std_3_monthsshop_id_item_category_id',
#        'item_price_std_6_monthsshop_id_item_category_id',
#        'item_cnt_day_std_1_monthitem_id',
#        'item_cnt_day_std_1_month_agoitem_id',
#        'item_cnt_day_std_3_monthsitem_id', 'item_cnt_day_std_6_monthsitem_id',
#        'item_cnt_day_sum_1_monthitem_id',
#        'item_cnt_day_sum_1_month_agoitem_id',
#        'item_cnt_day_sum_3_monthsitem_id', 'item_cnt_day_sum_6_monthsitem_id',
#        'item_price_std_1_monthitem_id', 'item_price_std_1_month_agoitem_id',
#        'item_price_std_3_monthsitem_id', 'item_price_std_6_monthsitem_id'],
#       dtype='object')
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-42-0c1c4ebf0dc7> in <module>()
#      31                             on=tolist(agg_keys) + ['year', 'month'],
#      32                             how='left',
# ---> 33                             suffixes=('','_'.join(tolist(agg_keys)))
#      34                            )
#      35 print(df_agg_train.shape)
#
# ~/.local/lib/python3.5/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      56                          copy=copy, indicator=indicator,
#      57                          validate=validate)
# ---> 58     return op.get_result()
#      59
#      60
#
# ~/.local/lib/python3.5/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     594             [(ldata, lindexers), (rdata, rindexers)],
#     595             axes=[llabels.append(rlabels), join_index],
# --> 596             concat_axis=0, copy=self.copy)
#     597
#     598         typ = self.left._constructor
#
# ~/.local/lib/python3.5/site-packages/pandas/core/internals.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    5201         else:
#    5202             b = make_block(
# -> 5203                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    5204                 placement=placement)
#    5205         blocks.append(b)
#
# ~/.local/lib/python3.5/site-packages/pandas/core/internals.py in concatenate_join_units(join_units, concat_axis, copy)
#    5330     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#    5331                                          upcasted_na=upcasted_na)
# -> 5332                  for ju in join_units]
#    5333
#    5334     if len(to_concat) == 1:
#
# ~/.local/lib/python3.5/site-packages/pandas/core/internals.py in <listcomp>(.0)
#    5330     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#    5331                                          upcasted_na=upcasted_na)
# -> 5332                  for ju in join_units]
#    5333
#    5334     if len(to_concat) == 1:
#
# ~/.local/lib/python3.5/site-packages/pandas/core/internals.py in get_reindexed_values(self, empty_dtype, upcasted_na)
#    5630             for ax, indexer in self.indexers.items():
#    5631                 values = algos.take_nd(values, indexer, axis=ax,
# -> 5632                                        fill_value=fill_value)
#    5633
#    5634         return values
#
# ~/.local/lib/python3.5/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1377             out = np.empty(out_shape, dtype=dtype, order='F')
#    1378         else:
# -> 1379             out = np.empty(out_shape, dtype=dtype)
#    1380
#    1381     func = _get_take_nd_function(arr.ndim, arr.dtype, out.dtype, axis=axis,
#
# MemoryError:

# %%
for agg_keys, agg_df in aggs.items():
    print(agg_df.columns)
    print(df_agg_train.columns)
    df_agg_train = pd.merge(df_agg_train,
                            agg_df, 
                            on=tolist(agg_keys) + ['year', 'month'], 
                            how='left', 
                            suffixes=('','_'.join(tolist(agg_keys)))
                           )
# Out:
# Index(['item_cnt_day_std_1_month', 'item_cnt_day_std_1_month_ago',
#        'item_cnt_day_std_3_months', 'item_cnt_day_std_6_months',
#        'item_cnt_day_sum_1_month', 'item_cnt_day_sum_1_month_ago',
#        'item_cnt_day_sum_3_months', 'item_cnt_day_sum_6_months',
#        'item_price_std_1_month', 'item_price_std_1_month_ago',
#        'item_price_std_3_months', 'item_price_std_6_months', 'month',
#        'shop_id__1_month', 'shop_id__1_month_ago', 'shop_id__3_months',
#        'shop_id__6_months', 'year'],
#       dtype='object')
# Index(['shop_id', 'item_id', 'item_category_id', 'big_category', 'month',
#        'year', 'item_cnt_day'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'shop_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-e28320e1c980> in <module>()
#       6                             on=tolist(agg_keys) + ['year', 'month'],
#       7                             how='left',
# ----> 8                             suffixes=('','_'.join(tolist(agg_keys)))
#       9                            )
#
# ~/.local/lib/python3.5/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      55                          right_index=right_index, sort=sort, suffixes=suffixes,
#      56                          copy=copy, indicator=indicator,
# ---> 57                          validate=validate)
#      58     return op.get_result()
#      59
#
# ~/.local/lib/python3.5/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     563         (self.left_join_keys,
#     564          self.right_join_keys,
# --> 565          self.join_names) = self._get_merge_keys()
#     566
#     567         # validate the merge keys dtypes. We may need to coerce
#
# ~/.local/lib/python3.5/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     822                     if not is_rkey(rk):
#     823                         if rk is not None:
# --> 824                             right_keys.append(right[rk]._values)
#     825                         else:
#     826                             # work-around for merge_asof(right_index=True)
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/.local/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/.local/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'shop_id'

# %%
df_agg_train.isnull().sum().sum()
# Out:
# 36296002

# %%
df_agg_train.head()
# Out:
#    shop_id  item_id  item_category_id big_category  month  year  item_cnt_day  \
# 0        2       32                40         Кино      8  2015           1.0
# 1        2       32                40         Кино      9  2014           2.0
# 2        2       33                37         Кино      7  2015           1.0
# 3        2       33                37         Кино      9  2014           1.0
# 4        2       70                49        Книги      8  2015           1.0
#
#    item_cnt_day_sum  item_cnt_day_std  item_price_std  \
# 0            2432.0          1.228767     2082.104295
# 1               NaN               NaN             NaN
# 2               NaN               NaN             NaN
# 3               NaN               NaN             NaN
# 4            2432.0          1.228767     2082.104295
#
#                     ...                    item_price_std1_month_ago_item_id  \
# 0                   ...                                                  NaN
# 1                   ...                                                  NaN
# 2                   ...                                                  NaN
# 3                   ...                                                  NaN
# 4                   ...                                                  NaN
#
#    item_cnt_day_sum1_month_ago_shop_id_big_category  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    item_cnt_day_std1_month_ago_shop_id_big_category  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    item_price_std1_month_ago_shop_id_big_category  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    item_cnt_day_sum1_month_ago_item_category_id  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    item_cnt_day_std1_month_ago_item_category_id  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    item_price_std1_month_ago_item_category_id  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    item_cnt_day_sum1_month_ago_big_category  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    item_cnt_day_std1_month_ago_big_category  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    item_price_std1_month_ago_big_category
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 343 columns]

# %%
df_agg_train.shape[0] * df_agg_train.shape[1]
# Out:
# 47795335

# %%
df_agg_train = df_train[['shop_id', 'item_id', 'item_category_id', 'big_category', 'month', 'year', 'date', 'item_cnt_day']]
df_agg_train = df_agg_train.groupby(x_cols, as_index=False)['item_cnt_day'].sum()
df_agg_train
# Out:
#          shop_id  item_id  item_category_id big_category  month  year  \
# 0              0       30                40         Кино      2  2013
# 1              0       31                37         Кино      2  2013
# 2              0       32                40         Кино      1  2013
# 3              0       32                40         Кино      2  2013
# 4              0       33                37         Кино      1  2013
# 5              0       33                37         Кино      2  2013
# 6              0       35                40         Кино      1  2013
# 7              0       35                40         Кино      2  2013
# 8              0       36                37         Кино      2  2013
# 9              0       40                57       Музыка      2  2013
# 10             0       42                57       Музыка      2  2013
# 11             0       43                40         Кино      1  2013
# 12             0       49                57       Музыка      2  2013
# 13             0       51                57       Музыка      1  2013
# 14             0       51                57       Музыка      2  2013
# 15             0       57                57       Музыка      2  2013
# 16             0       59                57       Музыка      2  2013
# 17             0       61                43        Книги      1  2013
# 18             0       75                40         Кино      1  2013
# 19             0       85                37         Кино      2  2013
# 20             0       88                40         Кино      1  2013
