# %%
import pandas as pd
df = pd.read_hdf('../data/processed/train/aggr_train_zeros.hdf')
df.head()
# Out:
#    ID  shop_id  item_id  year  month  \
# 0   0        5     5037  2014     10
# 1   2        5     5233  2014     10
# 2  15        5     4872  2014     10
# 3  21        5     5002  2014     10
# 4  23        5     5814  2014     10
#
#                                            item_name  item_category_id  \
# 0                     NHL 15 [PS3, русские субтитры]                19
# 1  Need for Speed Rivals (Essentials) [PS3, русск...                19
# 2  Minecraft. Playstation 3 Edition [PS3, русская...                19
# 3               NBA 2K16 [PS3, русская документация]                19
# 4  Plants vs. Zombies Garden Warfare [PS3, русска...                19
#
#   item_category_name first_big_category last_big_category      ...       \
# 0         Игры - PS3               Игры               PS3      ...
# 1         Игры - PS3               Игры               PS3      ...
# 2         Игры - PS3               Игры               PS3      ...
# ...

# %%
df.columns
# Out:
# Index(['ID', 'shop_id', 'item_id', 'year', 'month', 'item_name',
#        'item_category_id', 'item_category_name', 'first_big_category',
#        'last_big_category',
#        ...
#        'count_aggr_2_quartals_ago_city_first_big_category',
#        'count_aggr_year_city_first_big_category',
#        'count_aggr_1_month_ago_city_last_big_category',
#        'count_aggr_1_month_city_last_big_category',
#        'count_aggr_3_months_city_last_big_category',
#        'count_aggr_6_months_city_last_big_category',
#        'count_aggr_2_quartals_ago_city_last_big_category',
#        'count_aggr_year_city_last_big_category', 'fridays', 'item_cnt_day'],
#       dtype='object', length=132)

# %%
df['mall']
# Out:
# 0          Мармелад
# 1          Мармелад
# 2          Мармелад
# 3          Мармелад
# 4          Мармелад
# 5          Мармелад
# 6          Мармелад
# 7          Мармелад
# 8          Мармелад
# 9          Мармелад
# 10         Мармелад
# 11         Мармелад
# 12         Мармелад
# 13         Мармелад
# 14         Мармелад
# 15         Мармелад
# 16         Мармелад
# 17         Мармелад
# 18         Мармелад
# 19         Мармелад
# 20         Мармелад
# 21         Мармелад
# 22         Мармелад
# 23         Мармелад
# 24         Мармелад
# 25         Мармелад
# 26         Мармелад
# 27         Мармелад
# 28         Мармелад
# 29         Мармелад
#              ...
# 2784570    ПаркХаус
# 2784571    ПаркХаус
# 2784572    ПаркХаус
# 2784573    ПаркХаус
# 2784574    ПаркХаус
# 2784575    ПаркХаус
# 2784576    ПаркХаус
# 2784577    ПаркХаус
# 2784578    ПаркХаус
# 2784579    ПаркХаус
# 2784580    ПаркХаус
# 2784581    ПаркХаус
# 2784582    ПаркХаус
# 2784583    ПаркХаус
# ...
