# %%
import pandas as pd
df = pd.read_csv('../data/processed/df_train_w_date_features.csv')
df.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  2013-01-02               0       59    22154      999.00           1.0
# 1  2013-01-03               0       25     2552      899.00           1.0
# 2  2013-01-05               0       25     2552      899.00          -1.0
# 3  2013-01-06               0       25     2554     1709.05           1.0
# 4  2013-01-15               0       25     2555     1099.00           1.0
#
#    day  month  year  weekday     ...      to_new_year_days  \
# 0    2      1  2013        2     ...                   363
# 1    3      1  2013        3     ...                   362
# 2    5      1  2013        5     ...                   360
# 3    6      1  2013        6     ...                   359
# 4   15      1  2013        1     ...                   350
#
#    is_feb_special_time  feb_special_gaussian  from_feb_special_days  \
# 0                False                   0.0                    314
# ...

# %%
df.columns
# Out:
# Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#        'item_cnt_day', 'day', 'month', 'year', 'weekday', 'days_passed',
#        'is_new_year', 'new_year_gaussian', 'from_new_year_days',
#        'to_new_year_days', 'is_feb_special_time', 'feb_special_gaussian',
#        'from_feb_special_days', 'to_feb_special_days', 'is_nov_special_time',
#        'nov_special_gaussian', 'from_nov_special_days', 'to_nov_special_days',
#        'is_holiday'],
#       dtype='object')
