# %%
import pandas as pd 
df_items = pd.read_csv('../data/raw/items.csv')
df_item_categories = pd.read_csv('../data/raw/item_categories.csv')
df_items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
df_item_categories.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
df_item_categories['first_big_category'] = df_item_categories['item_category_name'].str.split().apply(lambda x: x[0])

# %%
df_item_categories['last_big_category'] = df_item_categories['item_category_name'].str.split().apply(lambda x: x[-1])

# %%
df_item_categories.to_hdf('../data/processed/dimensions/item_categories.hdf', 'categories', mode='w')

# %%
df_items.to_hdf('../data/processed/dimensions/items.hdf', 'items', mode='w')

# %%
df_shops.to_hdf('../data/processed/dimensions/shops.hdf', 'shops', mode='w')

# %%
df_item_categories['item_category_name'].str.split().apply(lambda x: x[0]).value_counts()
# Out:
# Игры          14
# Книги         13
# Подарки       12
# Игровые        8
# Аксессуары     7
# Музыка         6
# Программы      6
# Карты          5
# Кино           5
# Чистые         2
# Служебные      2
# Доставка       1
# Билеты         1
# Элементы       1
# PC             1
# Name: item_category_name, dtype: int64

# %%
df_items['item_name'].head(12)
# Out:
# 0             ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D
# 1     !ABBYY FineReader 12 Professional Edition Full...
# 2         ***В ЛУЧАХ СЛАВЫ   (UNV)                    D
# 3       ***ГОЛУБАЯ ВОЛНА  (Univ)                      D
# 4           ***КОРОБКА (СТЕКЛО)                       D
# 5     ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ  (UNI)         ...
# 6              ***УДАР ПО ВОРОТАМ (UNI)               D
# 7            ***УДАР ПО ВОРОТАМ-2 (UNI)               D
# 8              ***ЧАЙ С МУССОЛИНИ                     D
# 9         ***ШУГАРЛЭНДСКИЙ ЭКСПРЕСС (UNI)             D
# 10            *ЗА ГРАНЬЮ СМЕРТИ                       D
# 11            *ЛИНИЯ СМЕРТИ                           D
# Name: item_name, dtype: object

# %%
df_items['item_name'].str.split().apply( lambda x: x[-1]).value_counts()
# Out:
# версия]                           3366
# (BD)                              1693
# (регион)                          1474
# (фирм.)                            662
# (Jewel)                            611
# LP                                 517
# субтитры]                          396
# (digipack)                         348
# (Регион)                           336
# документация]                      283
# BD)                                281
# 2LP                                211
# 7"                                 206
# (jewel)                            203
# DVD                                187
# 2                                  186
# 2CD                                178
# (rem)                              165
# Jewel]                             165
# (Digipack)                         164
# 1                                  142
# M                                  116
# L                                  103
# wd                                  98
# ...

# %%
df_shops = pd.read_csv('../data/raw/shops.csv')
df_shops.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
df_shops['city'] = df_shops['shop_name'].str.split().apply(lambda x: x[0])

# %%
df_shops['mall'] = df_shops['shop_name'].str.split('"').apply(lambda x: '' if len(x) < 2 else x[1])

# %%
df_shops.head(30)
# Out:
#                              shop_name  shop_id              city  \
# 0        !Якутск Орджоникидзе, 56 фран        0           !Якутск
# 1        !Якутск ТЦ "Центральный" фран        1           !Якутск
# 2                     Адыгея ТЦ "Мега"        2            Адыгея
# 3       Балашиха ТРК "Октябрь-Киномир"        3          Балашиха
# 4             Волжский ТЦ "Волга Молл"        4          Волжский
# 5               Вологда ТРЦ "Мармелад"        5           Вологда
# 6           Воронеж (Плехановская, 13)        6           Воронеж
# 7               Воронеж ТРЦ "Максимир"        7           Воронеж
# 8         Воронеж ТРЦ Сити-Парк "Град"        8           Воронеж
# 9                    Выездная Торговля        9          Выездная
# 10          Жуковский ул. Чкалова 39м?       10         Жуковский
# 11          Жуковский ул. Чкалова 39м²       11         Жуковский
# 12                 Интернет-магазин ЧС       12  Интернет-магазин
# ...

# %%
df_shops_read = pd.read_hdf('../data/processed/dimensions/items')
# Out:
#                                           shop_name  shop_id  \
# 0                     !Якутск Орджоникидзе, 56 фран        0
# 1                     !Якутск ТЦ "Центральный" фран        1
# 2                                  Адыгея ТЦ "Мега"        2
# 3                    Балашиха ТРК "Октябрь-Киномир"        3
# 4                          Волжский ТЦ "Волга Молл"        4
# 5                            Вологда ТРЦ "Мармелад"        5
# 6                        Воронеж (Плехановская, 13)        6
# 7                            Воронеж ТРЦ "Максимир"        7
# 8                      Воронеж ТРЦ Сити-Парк "Град"        8
# 9                                 Выездная Торговля        9
# 10                       Жуковский ул. Чкалова 39м?       10
# 11                       Жуковский ул. Чкалова 39м²       11
# 12                              Интернет-магазин ЧС       12
# 13                              Казань ТЦ "Бехетле"       13
# ...
